# %%
class Node:
  def __init__(self, datavalue=None):
    self.datavalue = datavalue
    self.nextvalue = None

n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

print (n1.datavalue)
print (n2.datavalue)
print (n3.datavalue)
# Out:
# Januari
# Februari
# Maret

# %%
class Node:
  def __init__(self, datavalue=None):
    self.datavalue = datavalue
    self.nextvalue = None

n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class Linkedlist:
  def __init__(self):
    self.headvalue = None

Li = Linkedlist()
Li.headvalue = n1

# Link first Node to second node
Li.headvalue.nextvalue = n2

# Link second Node to third node
n1.nextvalue = n3

# %%
class Node:
  def __init__(self, datavalue=None):
    self.datavalue = datavalue
    self.nextvalue = None

n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class Linkedlist:
  def __init__(self):
    self.headvalue = None

# Print the linked list
  def listprint(self):
    printval = self.headvalue
    while printval is not None:
      print (printval.datavalue)
      printval = printval.nextvalue

Li = Linkedlist()
Li.headvalue = n1

# Link first Node to second node
Li.headvalue.nextvalue = n2

# Link second Node to third node
n1.nextvalue = n3

Li.listprint()
# Out:
# Januari
# Maret

# %%
class Node:
  def __init__(self, datavalue=None):
    self.datavalue = datavalue
    self.nextvalue = None

#Create node
n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

print (n1.datavalue)
print (n2.datavalue)
print (n3.datavalue)
class Linkedlist:
  def __init__(self):
    self.headvalue = None

# Print the linked list
  def listprint(self):
    printval = self.headvalue
    while printval is not None:
      print (printval.datavalue)
      printval = printval.nextvalue

#Create atribut add begining to Update the new nodes next val to existing node
  def AddBegining(self, newdata):
    NewNode = Node(newdata)
    NewNode.nextvalue = self.headvalue
    self.headvalue = NewNode

Li = Linkedlist()
Li.headvalue = n1

# Link first Node to second node
Li.headvalue.nextvalue = n2

# Link second Node to third node
n1.nextvalue = n3

Li.AddBegining("Start")
Li.listprint()
# Out:
# Januari
# Februari
# Maret
# Start
# Januari
# Maret

# %%
class Node:
  def __init__(self, datavalue=None):
    self.datavalue = datavalue
    self.nextvalue = None

n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class Linkedlist:
  def __init__(self):
    self.headvalue = None

# Print the linked list
  def listprint(self):
    printval = self.headvalue
    while printval is not None:
      print (printval.datavalue)
      printval = printval.nextvalue

# Function to add node in the middle
  def AddInbetween(self,middle_node,newdata):
    if middle_node is None:
      print("The mentioned node is absent")
      return
    NewNode = Node(newdata)
    NewNode.nextvalue = middle_node.nextvalue
    middle_node.nextvalue = NewNode

Li = Linkedlist()
Li.headvalue = n1

# Link first Node to second node
Li.headvalue.nextvalue = n2

# Link second Node to third node
n1.nextvalue = n3

#Add node afte n1
Li.AddInbetween(n1,"April")
Li.listprint()
# Out:
# Januari
# April
# Maret

# %%
class Node:
  def __init__(self, datavalue=None):
    self.datavalue = datavalue
    self.nextvalue = None

n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class Linkedlist:
  def __init__(self):
    self.headvalue = None

# Print the linked list
  def listprint(self):
    printval = self.headvalue
    while printval is not None:
      print (printval.datavalue)
      printval = printval.nextvalue

#Function to add newnode in the end
  def AddInEnd(self, newdata):
    NewNode = Node(newdata)
    if self.headvalue is None:
      self.headvalue = NewNode
      return
    last = self.headvalue
    while (last.nextvalue):
      last = last.nextvalue
    last.nextvalue=NewNode


Li = Linkedlist()
Li.headvalue = n1

# Link first Node to second node
Li.headvalue.nextvalue = n2

# Link second Node to third node
n1.nextvalue = n3

# Add node in the end
Li.AddInEnd("Desember")
Li.listprint()
# Out:
# Januari
# Maret
# Desember

# %%
class Node:
  def __init__(self, datavalue=None):
    self.datavalue = datavalue
    self.nextvalue = None

n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class Linkedlist:
  def __init__(self):
    self.headvalue = None

# Print the linked list
  def listprint(self):
    printval = self.headvalue
    while printval is not None:
      print (printval.datavalue)
      printval = printval.nextvalue

#Function to add node in the beginning
  def AddBegining(self, newdata):
    NewNode = Node(newdata)
# Update the new nodes next val to existing node
    NewNode.nextvalue = self.headvalue
    self.headvalue = NewNode

# Function to remove node by key
  def RemoveNode(self, Removekey):
    HeadVal = self.headvalue
    if (HeadVal is not None):
      if (HeadVal.datavalue == Removekey):
        self.headvalue = HeadVal.nextvalue
        HeadVal = None
        return

    while (HeadVal is not None):
      if HeadVal.datavalue == Removekey:
        break
      prev = HeadVal
      HeadVal = HeadVal.nextvalue
    if (HeadVal == None):
      return
    prev.nextvalue = HeadVal.nextvalue
    HeadVal = None

#Create linked list named li
Li = Linkedlist()

# Add node
Li.AddBegining("April")
Li.AddBegining("Maret")
Li.AddBegining("Februari")
print('Sebelum dilakukan remove')
Li.listprint()
print("=======================================================================")

# remove node by key = "Maret"
Li.RemoveNode("Maret")
print('Setelah dilakukan remove ')
Li.listprint()
# Out:
# Sebelum dilakukan remove
# Februari
# Maret
# April
# ...
# Setelah dilakukan remove
# Februari
# April

# %%
class Node:
  def __init__(self, datavalue=None):
    self.datavalue = datavalue
    self.nextvalue = None

n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class Linkedlist:
  def __init__(self):
    self.headvalue = None

# Print the linked list
  def listprint(self):
    printval = self.headvalue
    while printval is not None:
      print (printval.datavalue)
      printval = printval.nextvalue

#Function to add node in the beginning
  def AddBegining(self, newdata):
    NewNode = Node(newdata)
# Update the new nodes next val to existing node
    NewNode.nextvalue = self.headvalue
    self.headvalue = NewNode

# Function to remove first node
  def RemoveFirst(self):
    afterhead = self.headvalue
    self.headvalue = afterhead.nextvalue

#Create linked list named li
Li = Linkedlist()

# Add node
Li.AddBegining("April")
Li.AddBegining("Maret")
Li.AddBegining("Februari")
print('Sebelum dilakukan remove')
Li.listprint()
print("=======================================================================")

# remove first node
Li.RemoveFirst()
print('Setelah dilakukan remove ')
Li.listprint()
# Out:
# Sebelum dilakukan remove
# Februari
# Maret
# April
# ...
# Setelah dilakukan remove
# Maret
# April

# %%
class Node:
  def __init__(self, datavalue=None):
    self.datavalue = datavalue
    self.nextvalue = None

n1 = Node("Januari")
n2 = Node("Februari")
n3 = Node("Maret")

class Linkedlist:
  def __init__(self):
    self.headvalue = None

# Print the linked list
  def listprint(self):
    printval = self.headvalue
    while printval is not None:
      print (printval.datavalue)
      printval = printval.nextvalue

#Function to add newnode in the end
  def AddInEnd(self, newdata):
    NewNode = Node(newdata)
    if self.headvalue is None:
      self.headvalue = NewNode
      return
    last = self.headvalue
    while (last.nextvalue):
      last = last.nextvalue
    last.nextvalue=NewNode

#Function to remove end node
  def RemoveEnd(self):
    last = self.headvalue
    while (last is not None):
      if last.nextvalue == None:
        break
      prev = last
      last = last.nextvalue
    if (last == None):
      return
    prev.nextvalue = last.nextvalue
    last = None
#Create linked list named li
Li = Linkedlist()

# Add node
Li.AddInEnd("Januari")
Li.AddInEnd("Februari")
Li.AddInEnd("Maret")
print('Sebelum dilakukan remove')
Li.listprint()
print("=======================================================================")

# remove last node
Li.RemoveEnd()
print('Setelah dilakukan remove ')
Li.listprint()
# Out:
# Sebelum dilakukan remove
# Januari
# Februari
# Maret
# ...
# Setelah dilakukan remove
# Januari
# Februari
